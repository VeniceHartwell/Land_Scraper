# %% [markdown]
# # Visualize Landmodo Data
#
# ## Import libraries, csv files, etc for setup.

# %%
# Import libraries for visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import data cleaning and enriching file
from src.cleaning import*

# Plot settings
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# Import and check csv file
input_date = input_date() # test zip: 79847
df = pd.read_csv (f'output/landmodo_search_{input_date}.csv', encoding='latin') # take file with user input date
#Remove unnamed index column from csv
#df = df.set_index('Unnamed: 0')
#df.index.name = None
#df.sample(5)
df
# Out:
# Enter a date in the "YYYY-MM-DD" format to import a CSV from: 2022-07-26
#     Zip Code  Location State Country  Parcel Size (acres)  Parcel Price  \
# 0      79847  Cornudas    TX     USA                20.18       18000.0
# 1      79847  Cornudas    TX     USA                20.00       18000.0
# 2      79847  Cornudas    TX     USA                20.00       18000.0
# 3      79847  Cornudas    TX     USA                20.00       20000.0
# 4      79847  Cornudas    TX     USA                20.00       18000.0
# 5      79847  Cornudas    TX     USA                18.00       18000.0
# 6      79855  Van Horn    TX     USA                15.64        7500.0
# 7      79855  Van Horn    TX     USA                11.00        5500.0
# 8      79855  Van Horn    TX     USA                11.00        5500.0
# 9      79855  Van Horn    TX     USA                11.00        5500.0
# 10     79855  Van Horn    TX     USA                12.92        9995.0
# 11     79855  Van Horn    TX     USA                12.92        9995.0
# 12     79855  Van Horn    TX     USA                11.00        6500.0
# 13     79855  Van Horn    TX     USA                11.00        9995.0
# 14     79855  Van Horn    TX     USA                11.00        9995.0
# 15     92301  Adelanto    CA     USA                 2.29        9995.0
# 16     92301  Adelanto    CA     USA                 2.50       13995.0
# 17     92301  Adelanto    CA     USA                 2.28       14995.0
#
#                                          Listing Name         Listing Author  \
# 0   LAND FOR SALE â How to grow Old & Rich toget...              LandJakes
# 1   Invest 20 Acres or Neighboring Lots in Cornuda...              LandJakes
# 2   Invest 20 Acres Land in Hudspeth County, TX. N...              LandJakes
# 3   Summery Living in The Sunny Texas! Own 20 Acre...              LandJakes
# 4   Invest 20 Acres or Neighboring Lots in Cornuda...              LandJakes
# 5   Invest 20 Acres Land in Hudspeth County, TX. N...              LandJakes
# 6                                  Van Horn, TX 79855   Auction Flippers LLC
# 7                                  Van Horn, TX 79855   Auction Flippers LLC
# 8                                  Van Horn, TX 79855   Auction Flippers LLC
# 9                                  Van Horn, TX 79855   Auction Flippers LLC
# 10                                 Van Horn, TX 79855   Auction Flippers LLC
# 11                                 Van Horn, TX 79855   Auction Flippers LLC
# 12                                 Van Horn, TX 79855   Auction Flippers LLC
# 13                                 Van Horn, TX 79855   Auction Flippers LLC
# 14                                 Van Horn, TX 79855   Auction Flippers LLC
# 15  2.29 Acres Adelanto, San Bernardino County, CA...          Patrick Elder
# 16  Own This 2.50 Acre Land in Adelanto! Perfect S...          Patrick Elder
# 17   Located in Adelanto, CA! 2.28 Acres Vacant Land!          Patrick Elder
#
#       Post Date
# 0    04/14/2022
# 1    03/04/2022
# 2    03/04/2022
# 3    03/04/2022
# 4    02/10/2022
# 5    02/10/2022
# 6    06/06/2022
# 7    06/06/2022
# 8    06/06/2022
# 9    06/06/2022
# 10   06/03/2022
# 11   06/03/2022
# 12   06/03/2022
# 13   06/03/2022
# 14   06/03/2022
# 15   06/07/2022
# 16   07/06/2022
# 17   06/06/2022

# %% [markdown]
# ## Format dataframes to work with visualization tools.

# %%
# Set Zip Code to string values
df.astype({'Zip Code': 'str'}).dtypes

# Create a new dataframe with average prices per acre for each zip code.
avg_df = avg_df(df)
avg_df
# Out:
#    Zip Code  Avg Acre Price
# 0     79847      930.783551
# 1     79855      655.749907
# 2     92301     5514.144272

# %% [markdown]
# ## Parcel Price and Acreage by Zip Code

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12,4))

sns.barplot(data=df, x="Zip Code", y="Parcel Price", ax=axs[0])
sns.barplot(data=df, x="Zip Code", y="Parcel Price", hue="Parcel Size (acres)", ax=axs[1])
plt.show()
fig.figure.savefig(f"output/images/price_acreage_barcharts_{input_date}.png", dpi=1000)

# %% [markdown]
# ## Price per Acre (Box Plot)

# %%
ax = plt.subplot()
sns.boxplot(x="Zip Code", y="Parcel Price", data=df)
ax.set(xlabel='Zip Code', ylabel='Price', title="Average Price per Acre")

fig.suptitle('Price per Acre')
fig.figure.savefig(f"output/images/price_per_acre_boxplot_{input_date}.png", dpi=1000)

# %% [markdown]
# ## Average Price per Acre

# %%
sns.barplot(data=avg_df, x="Zip Code", y="Avg Acre Price")
fig.suptitle('Average Price per Acre')
plt.show()
fig.figure.savefig(f"output/images/avg_price_per_acre_barchart_{input_date}.png", dpi=1000)

# %% [markdown]
# ## Images have been exported to the "output" > "images" folder with the date included.
